# %%
a = map(lambda x:((1+1/x)**x),range(1,101))

# %%
a

# %%
b = list(a)

# %%
b
# Out:
# [2.0,
#  2.25,
#  2.37037037037037,
#  2.44140625,
#  2.4883199999999994,
#  2.5216263717421135,
#  2.546499697040712,
#  2.565784513950348,
#  2.5811747917131984,
#  2.5937424601000023,
#  2.6041990118975287,
#  2.613035290224676,
#  2.6206008878857308,
#  2.6271515563008685,
#  2.6328787177279187,
#  2.6379284973666,
#  2.64241437518311,
#  2.6464258210976865,
#  2.650034326640442,
#  2.653297705144422,
#  2.656263213926108,
#  2.658969858537786,
#  2.6614501186387796,
#  2.663731258068599,
#  2.665836331487422,
#  2.6677849665337465,
#  2.6695939778125704,
#  2.6712778534408463,
#  2.6728491439808066,
#  2.6743187758703026,
#  2.6756963059146854,
#  2.676990129378183,
#  2.678207651253779,
#  2.6793554280957674,
#  2.6804392861534603,
#  2.6814644203008586,
#  2.6824354773085255,
#  2.6833566262745787,
#  2.6842316184670922,
#  2.685063838389963,
#  2.6858563475377526,
#  2.686611922032571,
#  2.687333085118294,
#  2.6880221353133043,
#  2.688681170884324,
#  2.689312111189782,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(1,101),list(map(lambda x:((1+1/x)**x),range(1,101))))
